# %%
import pandas as pd

# %%
lung_data = pd.read_csv('/scratch/project1/plco/lung_prsn.csv')

# %%
lung_data
# Out:
#         reasfolll  reassympl  reassurvl  reasothl  num_cancl  \
# 0             NaN        NaN        NaN       NaN          0
# 1             NaN        NaN        NaN       NaN          0
# 2             NaN        NaN        NaN       NaN          0
# 3             NaN        NaN        NaN       NaN          0
# 4             NaN        NaN        NaN       NaN          0
# ...           ...        ...        ...       ...        ...
# 154882        NaN        NaN        NaN       NaN          0
# 154883        NaN        NaN        NaN       NaN          0
# 154884        NaN        NaN        NaN       NaN          0
# 154885        0.0        0.0        NaN       1.0          1
# 154886        NaN        NaN        NaN       NaN          0
#
#                reasothl_txt  lung_cancer  intstatl_cat  lung_stage  \
# 0                       NaN            0             0         NaN
# 1                       NaN            0             0         NaN
# ...
